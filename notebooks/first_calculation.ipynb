# %%
from crispy.notebook import calculation

# %% [markdown]
# ## Create the calculation instance.

# %%
calc = calculation("Fe3+", "C3v", "XAS", "L2,3 (2p)")

# %% [markdown]
# ## Select the spectra that you want to calculate.

# %%
calc.spectra.show()
# Out:
# Isotropic Absorption: ☑
# Absorption: ☐
# Circular Dichroic: ☐
# Linear Dichroic: ☐

# %%
calc.spectra.enable("Circular Dichroic")

# %%
calc.spectra.show()
# Out:
# Isotropic Absorption: ☑
# Absorption: ☐
# Circular Dichroic: ☑
# Linear Dichroic: ☐

# %% [markdown]
# ## Set the calculation parameters.

# %%
calc.parameter("Magnetic Field", 17)

calc.xaxis.parameter("Gaussian", 0.24)
calc.xaxis.parameter("Lorentzian", 1.0)
# Out:
# True

# %%
parameters = [("Fk", 0.7), ("Gk", 0.7), ("10Dq(3d)", 2.8), ("Dσ(3d)", 0.07), ("Dτ(3d)", 0.12)]

for parameter in parameters:
    calc.hamiltonian.parameter(*parameter)

# %%
calc.hamiltonian.parameters()
# Out:
# General
#   Fk: 0.7
#   Gk: 0.7
#   Zeta: 1.0
#   Number of States: 252
#   Number of Configurations: 1
# Terms
#   Atomic
#     Initial Hamiltonian
#       U(3d,3d): [0.0]
#       F2(3d,3d): [12.0428, 0.7]
#       F4(3d,3d): [7.5345, 0.7]
#       ζ(3d): [0.0588, 1.0]
#     Final Hamiltonian
#       U(3d,3d): [0.0]
#       F2(3d,3d): [12.8179, 0.7]
#       F4(3d,3d): [8.023, 0.7]
#       U(2p,3d): [0.0]
#       F2(2p,3d): [7.4458, 0.7]
#       G1(2p,3d): [5.5659, 0.7]
#       G3(2p,3d): [3.166, 0.7]
#       ζ(3d): [0.0743, 1.0]
#       ζ(2p): [8.1988, 1.0]
#   Crystal Field
#     Initial Hamiltonian
#       10Dq(3d): [2.8]
#       Dσ(3d): [0.07]
#       Dτ(3d): [0.12]
#     Final Hamiltonian
#       10Dq(3d): [2.8]
#       Dσ(3d): [0.07]
#       Dτ(3d): [0.12]
#   Magnetic Field
#     Initial Hamiltonian
#       Bx: [0.0]
#       By: [0.0]
#       Bz: [0.0009840249061884281]
#     Final Hamiltonian
#       Bx: [0.0]
#       By: [0.0]
#       Bz: [0.0009840249061884281]
#   Exchange Field
#     Initial Hamiltonian
#       Hx: [0.0]
#       Hy: [0.0]
#       Hz: [0.0]
#     Final Hamiltonian
#       Hx: [0.0]
#       Hy: [0.0]
#       Hz: [0.0]

# %%
calc.run()
# Out:
# True

# %%
calc.output()
# Out:
# =============================================================
# ====    written by Maurits W. Haverkort                  ====
# ====    with contributions from:                         ====
# ====    Yi Lu, Robert Green, Sebastian Macke             ====
# ====    Marius Retegan, Martin Brass, and Simon Heinze   ====
# ====    (C) 1995-2018   All rights reserved              ====
# ====    www.quanty.org                                   ====
# ====    Beta version, be critical and report errors!!!   ====
# =============================================================
# ====    Version 0.6 Autumn 2018                          ====
# ====            compiled at: Nov 25 2018 at 23:23:12     ====
# =============================================================
# ====    When used in scientific publications please cite ====
# ====    one of the following papers as appropriate with  ====
# ====    respect to the methods used in your publication: ====
# ====    Phys. Rev. B 85, 165113 (2012)                   ====
# ====    Phys. Rev. B 90, 085102 (2014)                   ====
# ====    Euro Phys. Lett. 108, 57004 (2014)               ====
# ====    J. of Phys.: Conf. Series 712, 012001 (2016)     ====
# =============================================================
# Program executed on: Tue Jan 26 13:22:28 2021
# Running on host    : macretegan.esrf.fr
# number of available processors              : 0
# maximum number of threads in parallel region: 0
# Smallest positive float  : 2.225074E-308
# Smallest deviation from 1: 2.220446E-16
#
# Diagonal values of the initial crystal field Hamiltonian:
# ================
# Irrep.         E
# ================
# a1(t2g)   -1.980
# e(t2g)    -0.970
# e(eg)      1.960
# ================
# For the C3v symmetry, the crystal field Hamiltonian is not necessarily diagonal in
# the basis of the irreducible representations. See the König and Kremer book, page 56.
# The non-digonal element <e(t2g)|H|e(eg)> is 0.184.
#
# Analysis of the initial Hamiltonian:
# =================================================================================================================================
# State           E     <S^2>     <L^2>     <J^2>      <Sk>      <Lk>      <Jk>      <Tk>     <l.s>    <N_2p>    <N_3d>          dZ
# =================================================================================================================================
#     1   -6.876381    0.7646   24.1145   26.2957   -0.5012   -1.3948   -1.8960   -0.1105   -1.0134    6.0000    5.0000    9.96e-01
#     2   -6.871670    0.7646   24.0969   26.2713    0.5011    1.3879    1.8890    0.1108   -1.0150    6.0000    5.0000    4.21e-03
# =================================================================================================================================

# %% [markdown]
# ## Plot the calculated spectra.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

calc.spectra.plot(ax=ax)

ax.legend()
ax.grid()
ax.set_xlabel("Absorption Energy (eV)")
ax.set_ylabel("Intensity (a.u.)")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
